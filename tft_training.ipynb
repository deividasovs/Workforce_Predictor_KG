# %% [markdown]
# # ML project

# %%
import pytorch_lightning as pl
import numpy as np
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger
import torch
from sklearn.metrics import mean_absolute_error, mean_squared_error
from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet

from tft_architecture import tft, training, val_dataloader, train_dataloader, validation

import matplotlib.pyplot as plt
# Out:
# Number of parameters in network: 105.6k
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py:524: UserWarning: scale is below 1e-7 - consider not centering the data or using data with higher variance for numerical stability
#   warnings.warn(
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
#   rank_zero_warn(
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/utilities/parsing.py:262: UserWarning: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
#   rank_zero_warn(

# %%
# define trainer with early stopping
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=1, verbose=False, mode="min")
lr_logger = LearningRateMonitor()

pl.seed_everything(42)

trainer = pl.Trainer(
    gpus=0,
    gradient_clip_val=0.1,
    limit_train_batches=30,
    callbacks=[lr_logger, early_stop_callback],
)
# Out:
# Global seed set to 42
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:467: LightningDeprecationWarning: Setting `Trainer(gpus=0)` is deprecated in v1.7 and will be removed in v2.0. Please use `Trainer(accelerator='gpu', devices=0)` instead.
#   rank_zero_deprecation(
# GPU available: True (mps), used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/setup.py:200: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(

# %%
# Load the model
savedTft = TemporalFusionTransformer.load_from_checkpoint('./lightning_logs/version_36/checkpoints/epoch=20-step=630.ckpt')

# %%
# fit the model
trainer.fit(
    tft, train_dataloaders=train_dataloader, val_dataloaders=val_dataloader,
)
#savedTft
# Out:
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/loops/utilities.py:94: PossibleUserWarning: `max_epochs` was not set. Setting it to 1000 epochs. To train without an epoch limit, set `max_epochs=-1`.
#   rank_zero_warn(
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | MultiLoss                       | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 1
# 3  | prescalers                         | ModuleDict                      | 512
# 4  | static_variable_selection          | VariableSelectionNetwork        | 2.0 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 32.2 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 16.1 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 4.3 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 4.3 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 4.3 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 4.3 K
# 11 | lstm_encoder                       | LSTM                            | 8.4 K
# 12 | lstm_decoder                       | LSTM                            | 8.4 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 2.1 K
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 64
# 15 | static_enrichment                  | GatedResidualNetwork            | 5.3 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 4.2 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 2.2 K
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 4.3 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 2.2 K
# 20 | output_layer                       | ModuleList                      | 1.2 K
# ----------------------------------------------------------------------------------------
# 105 K     Trainable params
# 0         Non-trainable params
# 105 K     Total params
# 0.423     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
# Traceback (most recent call last):
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3016, in _dep_map
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#         from pytorch_forecasting.data.encoders import (from pytorch_forecasting.data.encoders import (
#
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 14, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 24, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 14, in <module>
#     from pytorch_lightning.callbacks.batch_size_finder import BatchSizeFinder
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/batch_size_finder.py", line 24, in <module>
#     from pytorch_lightning.callbacks.model_checkpoint import ModelCheckpoint
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/model_checkpoint.py", line 33, in <module>
#     from pytorch_lightning.callbacks.batch_size_finder import BatchSizeFinder
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/batch_size_finder.py", line 24, in <module>
#     return self.__dep_map
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2813, in __getattr__
#     exitcode = _main(fd, parent_sentinel)
#       File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
# from pytorch_lightning.callbacks.callback import Callback
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/callback.py", line 25, in <module>
#     from pytorch_lightning.callbacks.callback import Callback
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/callback.py", line 25, in <module>
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#     from pytorch_lightning.utilities.types import STEP_OUTPUT
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/utilities/types.py", line 34, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#     from pytorch_lightning.utilities.types import STEP_OUTPUT
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/utilities/types.py", line 27, in <module>
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 34, in <module>
#     import yaml
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/__init__.py", line 13, in <module>
#     from lightning_fabric.utilities.seed import seed_everything  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_fabric/__init__.py", line 23, in <module>
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     _METRIC_COLLECTION = Union[_METRIC, Mapping[str, _METRIC]]
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/typing.py", line 271, in inner
#     from torchmetrics import Metric
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/torchmetrics/__init__.py", line 23, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     from .cyaml import *
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/cyaml.py", line 7, in <module>
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     from lightning_fabric.fabric import Fabric  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_fabric/fabric.py", line 30, in <module>
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     from torchmetrics.classification import (  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/torchmetrics/classification/__init__.py", line 77, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     from yaml._yaml import CParser, CEmitter
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#   File "<frozen importlib._bootstrap>", line 398, in parent
#         self = reduction.pickle.load(from_parent)import pytorch_lightning as pl
#
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#         from pytorch_forecasting.data import (from pytorch_lightning.callbacks import Callback  # noqa: E402
#
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 27, in <module>
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     from pytorch_lightning.callbacks.progress import ProgressBarBase, RichProgressBar, TQDMProgressBar
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/progress/__init__.py", line 22, in <module>
#     from torchmetrics.classification.precision_recall import (KeyboardInterrupt
#
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
#     from lightning_fabric.loggers import Logger
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_fabric/loggers/__init__.py", line 15, in <module>
#     try:
# KeyboardInterrupt  File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
#
# from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 24, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1414, in find_spec
#     from pytorch_lightning.callbacks.model_checkpoint import ModelCheckpoint
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/model_checkpoint.py", line 33, in <module>
#     from lightning_fabric.loggers.tensorboard import TensorBoardLogger  # noqa: F401
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_fabric/loggers/tensorboard.py", line 26, in <module>
#     import yaml
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/__init__.py", line 8, in <module>
#     from .loader import *
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/loader.py", line 4, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1374, in _get_spec
# Traceback (most recent call last):
#     from pytorch_lightning.callbacks.progress.rich_progress import RichProgressBar  # noqa: F401  File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3016, in _dep_map
#
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/progress/rich_progress.py", line 27, in <module>
#     from lightning_fabric.utilities.cloud_io import get_filesystem
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_fabric/utilities/cloud_io.py", line 20, in <module>
# KeyboardInterrupt    from .reader import *
#
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/reader.py", line 45, in <module>
#     class Reader(object):
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/yaml/reader.py", line 137, in Reader
#     if _RICH_AVAILABLE:
# NON_PRINTABLE = re.compile('[^\x09\x0A\x0D\x20-\x7E\x85\xA0-\uD7FF\uE000-\uFFFD\U00010000-\U0010ffff]')
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 112, in __bool__
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/re.py", line 252, in compile
#     import fsspec
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/fsspec/__init__.py", line 12, in <module>
#     return self.__dep_map
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2813, in __getattr__
#     self._check_requirement()
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 103, in _check_requirement
#     from .compression import available_compressions
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/fsspec/compression.py", line 147, in <module>
#     pkg_resources.require(self.requirement)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 886, in require
#     needed = self.resolve(parse_requirements(requirements))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 780, in resolve
#         import lz4.frameraise AttributeError(attr)
#
#   File "<frozen importlib._bootstrap>", line 1007, in _find_and_load
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#     new_requirements = dist.requires(req.extras)[::-1]
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2734, in requires
#   File "<frozen importlib._bootstrap>", line 982, in _find_and_load_unlocked
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#   File "<frozen importlib._bootstrap>", line 925, in _find_spec
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#   File "<frozen importlib._bootstrap_external>", line 1414, in find_spec
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1386, in _get_spec
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#   File "<frozen importlib._bootstrap_external>", line 1513, in find_spec
#     dm = self._dep_map
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3018, in _dep_map
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 27, in <module>
#   File "<frozen importlib._bootstrap_external>", line 142, in _path_stat
#     from pytorch_lightning.callbacks.progress import ProgressBarBase, RichProgressBar, TQDMProgressBar
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/progress/__init__.py", line 22, in <module>
# KeyboardInterrupt
#     from pytorch_lightning.callbacks.progress.rich_progress import RichProgressBar  # noqa: F401
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/progress/rich_progress.py", line 27, in <module>
#     if _RICH_AVAILABLE:
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 112, in __bool__
#     self._check_requirement()
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 103, in _check_requirement
#     pkg_resources.require(self.requirement)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 886, in require
#     self.__dep_map = self._compute_dependencies()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3028, in _compute_dependencies
#     needed = self.resolve(parse_requirements(requirements))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 780, in resolve
#     new_requirements = dist.requires(req.extras)[::-1]
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2734, in requires
#     reqs.extend(parse_requirements(req))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3084, in parse_requirements
#     dm = self._dep_map
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3018, in _dep_map
#     yield Requirement(line)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3094, in __init__
#     self.__dep_map = self._compute_dependencies()
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3028, in _compute_dependencies
#     super(Requirement, self).__init__(requirement_string)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 98, in __init__
#     reqs.extend(parse_requirements(req))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3084, in parse_requirements
#     req = REQUIREMENT.parseString(requirement_string)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py", line 1644, in parseString
#     loc, tokens = self._parse( instring, 0 )
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py", line 1402, in _parseNoCache
#     yield Requirement(line)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 3094, in __init__
#     loc,tokens = self.parseImpl( instring, preloc, doActions )
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py", line 3400, in parseImpl
#     super(Requirement, self).__init__(requirement_string)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/requirements.py", line 120, in __init__
#     self.specifier = SpecifierSet(req.specifier)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/specifiers.py", line 677, in __init__
#     return _compile(pattern, flags)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/re.py", line 304, in _compile
#     loc, resultlist = self.exprs[0]._parse( instring, loc, doActions, callPreParse=False )
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py", line 1410, in _parseNoCache
#     p = sre_compile.compile(pattern, flags)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/sre_compile.py", line 768, in compile
#     retTokens = ParseResults( tokens, self.resultsName, asList=self.saveAsList, modal=self.modalResults )
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/pyparsing.py", line 363, in __new__
#     def __new__(cls, toklist=None, name=None, asList=True, modal=True ):
# KeyboardInterrupt
#     code = _code(p, flags)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/sre_compile.py", line 607, in _code
#     _compile(code, p.data, flags)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/sre_compile.py", line 120, in _compile
#     charset, hascased = _optimize_charset(av, iscased, tolower, fixes)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/sre_compile.py", line 311, in _optimize_charset
#     for i in r:
# KeyboardInterrupt
#     parsed.add(Specifier(specifier))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/specifiers.py", line 143, in __hash__
#     return hash(self._canonical_spec)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/specifiers.py", line 139, in _canonical_spec
#     return self._spec[0], canonicalize_version(self._spec[1])
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/utils.py", line 34, in canonicalize_version
#     version = Version(_version)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/version.py", line 282, in __init__
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 116, in spawn_main
#     release=tuple(int(i) for i in match.group("release").split(".")),
# KeyboardInterrupt
#     exitcode = _main(fd, parent_sentinel)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/multiprocessing/spawn.py", line 126, in _main
#     self = reduction.pickle.load(from_parent)
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/__init__.py", line 4, in <module>
#     from pytorch_forecasting.data import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/__init__.py", line 7, in <module>
#     from pytorch_forecasting.data.encoders import (
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/data/encoders.py", line 24, in <module>
#     from pytorch_forecasting.utils import InitialParameterRepresenterMixIn
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/utils.py", line 10, in <module>
#     import pytorch_lightning as pl
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/__init__.py", line 35, in <module>
#     from pytorch_lightning.callbacks import Callback  # noqa: E402
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/__init__.py", line 28, in <module>
#     from pytorch_lightning.callbacks.pruning import ModelPruning
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/callbacks/pruning.py", line 31, in <module>
#     from pytorch_lightning.core.module import LightningModule
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/core/__init__.py", line 16, in <module>
#     from pytorch_lightning.core.module import LightningModule
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/core/module.py", line 49, in <module>
#     from pytorch_lightning.loggers import Logger
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/loggers/__init__.py", line 19, in <module>
#     from pytorch_lightning.loggers.mlflow import _MLFLOW_AVAILABLE, MLFlowLogger  # noqa: F401
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/loggers/mlflow.py", line 41, in <module>
#     if _MLFLOW_AVAILABLE:
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 112, in __bool__
#     self._check_requirement()
#   File "/Users/deividas/Library/Python/3.9/lib/python/site-packages/lightning_utilities/core/imports.py", line 103, in _check_requirement
#     pkg_resources.require(self.requirement)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 886, in require
#     needed = self.resolve(parse_requirements(requirements))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 759, in resolve
#     env = Environment(self.entries)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 970, in __init__
#     self.scan(search_path)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 1002, in scan
#     for dist in find_distributions(item):
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2063, in find_on_path
#     for dist in factory(fullpath):
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2128, in distributions_from_metadata
#     yield Distribution.from_location(
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2588, in from_location
#     return cls(
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 2569, in __init__
#     self._version = safe_version(version)
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/__init__.py", line 1318, in safe_version
#     return str(packaging.version.Version(version))
#   File "/Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/version.py", line 288, in __init__
#     local=_parse_local_version(match.group("local")),
# KeyboardInterrupt
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_lightning/trainer/call.py:48: UserWarning: Detected KeyboardInterrupt, attempting graceful shutdown...
#   rank_zero_warn("Detected KeyboardInterrupt, attempting graceful shutdown...")

# %%
# load the best model according to the validation loss
# (given that we use early stopping, this is not necessarily the last epoch)
# Previous best trained model: /Users/deividas/Workplace/Workforce_Scheduler_Workspace/demand-forecaster-sam/lightning_logs/version_36/checkpoints/epoch=20-step=630.ckpt

#best_model_path = trainer.checkpoint_callback.best_model_path
#print(best_model_path)
#best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)
# TODO: Uncomment when testing!
best_tft = savedTft # TODO: Comment out when retraining again

raw_prediction, x = best_tft.predict(
    training,
    mode="raw",
    return_x=True,
)
# Out:
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/models/base_model.py:92: UserWarning: Not all dimensions are equal for tensors shapes. Example tensor torch.Size([64, 63, 1, 540]). Returning list instead of torch.Tensor.
#   warnings.warn(

# %%
# Save the temporal fusion transformer model
torch.save(trainer.checkpoint_callback.best_model_path, './Saved_Models/40MinsTrain_105k_params.pth')
# !zip  -r model.zip ./lightning_logs/version_36/*

# %%
# raw predictions are a dictionary from which all kind of information including quantiles can be extracted
raw_predictions, x = best_tft.predict(val_dataloader, mode="raw", return_x=True, show_progress_bar=True)
interpretation = best_tft.interpret_output(raw_predictions, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# Predict:   0%|          | 0/5 [00:00<?, ? batches/s]
# /Users/deividas/Library/Python/3.9/lib/python/site-packages/pytorch_forecasting/models/base_model.py:92: UserWarning: Not all dimensions are equal for tensors shapes. Example tensor torch.Size([128, 63, 1, 540]). Returning list instead of torch.Tensor.
#   warnings.warn(
# {'attention': <Figure size 640x480 with 1 Axes>,
#  'static_variables': <Figure size 700x250 with 1 Axes>,
#  'encoder_variables': <Figure size 700x575 with 1 Axes>,
#  'decoder_variables': <Figure size 700x400 with 1 Axes>}

# %%
for idx in range(3): 
    best_tft.plot_prediction(x, raw_predictions, idx=idx, add_loss_to_title=True)
    # plt.show only the first 100 samples
    plt.xlim(-50, 50)
    plt.show()

# %%
# Fix this error from the below code: TypeError: only integer tensors of a single element can be converted to an index
predictions, x = best_tft.predict(val_dataloader, return_x=True)

#predictions_vs_actuals = best_tft.calculate_prediction_actual_by_variable(x[0],predictions[0])
#best_tft.plot_prediction_actual_by_variable(predictions_vs_actuals);

# %% [markdown]
# ## Evaluation metrics

# %%
# Extract the actual target values from val_dataloader
actual_target = []
for batch in val_dataloader:
    actual_target.append(batch[1])

#Extract the predicted target values from predictions
predicted_target = []
for batch in predictions:
    predicted_target.append(batch)

# %%
actual_target[0][0][0]
# Out:
# tensor([[52., 61., 66.,  ...,  1.,  0., 48.],
#         [61., 66., 44.,  ...,  0., 48., 68.],
#         [66., 44., 36.,  ..., 48., 68., 94.],
#         ...,
#         [32., 39., 66.,  ..., 43., 44.,  6.],
#         [32., 39., 66.,  ..., 43., 44.,  6.],
#         [32., 39., 66.,  ..., 43., 44.,  6.]])

# %%
predicted_target[0]
# Out:
# tensor([[59.2935, 76.6990, 55.3939,  ...,  4.9358, 14.7542, 44.5555],
#         [80.0966, 56.4233, 44.5437,  ..., 14.5721, 44.4510, 60.8935],
#         [60.5634, 45.3977, 37.2157,  ..., 44.3277, 60.8278, 77.5935],
#         ...,
#         [28.8615, 38.0185, 68.4875,  ..., 46.0540, 40.8332, -1.8465],
#         [34.4159, 42.2379, 68.3006,  ..., 49.0793, 44.6370,  8.3422],
#         [35.0894, 43.3804, 70.8667,  ..., 50.3910, 45.6919,  7.3262]])

# %%
# Calculate SMAPE between actual and predicted values.
def smape(actual, predicted):
    actual = np.array(actual)
    predicted = np.array(predicted)
    smape_val = (100.0 / actual.size) * np.sum(2.0 * np.abs(predicted - actual) / (np.abs(actual) + np.abs(predicted)))
    return smape_val

# %%
# Calculating eval metrics for transaction_count
predicted_transactions = predicted_target[0][:63]
transactions = actual_target[0][0][0][:63]

mse = mean_squared_error(transactions, predicted_transactions)
mae = mean_absolute_error(transactions, predicted_transactions)
smape = smape(transactions, predicted_transactions)

print(f'MSE: {mse:.2f}, MAE: {mae:.2f}, SMAPE: {smape:.2f}')
# Out:
# MSE: 50.31, MAE: 5.45, SMAPE: 16.57
